# %% [markdown]
# # single-level

# %%
class Father():
    money = 10000
    bike = 'appache'

class Child(Father):
    bike = 'java'
    car = 'audi A6'
OF = Father()
OC = Child()

Child.money = 20000
print(Father.money)
print(OF.money)
print(Child.money)
print(OC.money)
# Out:
# 10000
# 10000
# 20000
# 20000

# %%
class Bank_v1:
    bank_Name='SBI'
    bank_ifsc='SBIN1234'
    bank_branch='Hyderabad'
    
    def __init__(self,n,a,ac,b):
            self.name=n
            self.age=a
            self.account=ac
            self.balance=b

    def customer_detail(self):
        print('customer name is ',self.name)
        print('customer age is ',self.age)
        print('customer account no. is ',self.account)
        print('customer balance is ',self.balance)

    @classmethod
    def display_bank_details(cls):
        print('bank name is',cls.bank_Name)
        print('bank ifsc is',cls.bank_ifsc)
        print('bank branch is',cls.bank_branch)

    @staticmethod
    def get_int_data(s):
        data=int(input(f'enter int data for {s}'))
        return data

    def withdrawl(self):
            amount=self.get_int_data('withdraw amount')
            if self.balance>=amount:
                self.balance-=amount
                print(amount,'withdrwal is successful')
                print(f'your balance is {self.balance}')
            else:
                print('low balance')
                print(f'your balance is {self.balance}')

class Bank_v2(Bank_v1):
    def deposite(self):
        amount=self.get_int_data('deposite amount')
        self.balance+=amount
        print(amount,'deposite is successfull')
        print(f'your balance is {self.balance}')

Akash=Bank_v2('Akash Gupta',23,78468482,10000000)
Akash.customer_detail()
Akash.withdrawl()
Akash.deposite()
# Out:
# customer name is  Akash Gupta
# customer age is  23
# customer account no. is  78468482
# customer balance is  10000000
# 20000 withdrwal is successful
# your balance is 9980000
# 20000 deposite is successfull
# your balance is 10000000

# %% [markdown]
# # single-level

# %%
class Bank_v1:
    bank_Name='SBI'
    bank_ifsc='SBIN1234'
    bank_branch='Hyderabad'
    
    def __init__(self,n,a,ac,b):
            self.name=n
            self.age=a
            self.account=ac
            self.balance=b

    def customer_detail(self):
        print('customer name is ',self.name)
        print('customer age is ',self.age)
        print('customer account is ',self.account)
        print('customer balance is ',self.balance)

    @classmethod
    def display_bank_details(cls):
        print('bank name is',cls.bank_Name)
        print('bank ifsc is',cls.bank_ifsc)
        print('bank branch is',cls.bank_branch)

    @staticmethod
    def get_int_data(s):
        data=int(input(f'enter int data for {s}'))
        return data

    def withdrawl(self):
            amount=self.get_int_data('withdraw amount')
            if self.balance>=amount:
                self.balance-=amount
                print(amount,'withdrwal is successful')
                print(f'your balance is {self.balance}')
            else:
                print('low balance')
                print(f'your balance is {self.balance}')

class Bank_v2(Bank_v1):
    bank_branch='Banglore'
    bank_mobile=8989898989

    def __init__(self,n,a,ac,b,p,ad):
            self.name=n
            self.age=a
            self.account=ac
            self.balance=b
            self.pin=p
            self.adhar=ad

    def customer_detail(self):
        print('customer name is ',self.name)
        print('customer age is ',self.age)
        print('customer account no. is ',self.account)
        print('customer balance is ',self.balance)
        print('customer pin is ',self.pin)
        print('customer adhar is ',self.adhar)


    @classmethod
    def display_bank_details(cls):
        print('bank name is',cls.bank_Name)
        print('bank ifsc is',cls.bank_ifsc)
        print('bank branch is',cls.bank_branch)
        print('bank mobile is',cls.bank_mobile)


    def deposite(self):
        amount=self.get_int_data('deposite amount')
        self.balance+=amount
        print(amount,'deposite is successfull')
        print(f'your balance is {self.balance}')

Akash=Bank_v2('Akash Gupta',23,78468482,10000000,477116,940597444444)
Akash.display_bank_details()
Akash.customer_detail()
Akash.withdrawl()
Akash.deposite()
# Out:
# bank name is SBI
# bank ifsc is SBIN1234
# bank branch is Banglore
# bank mobile is 8989898989
# customer name is  Akash Gupta
# customer age is  23
# customer account no. is  78468482
# customer balance is  10000000
# customer pin is  477116
# customer adhar is  940597444444
# 20000 withdrwal is successful
# your balance is 9980000
# 20000 deposite is successfull
# your balance is 10000000

# %% [markdown]
# # Hybrid inheritance

# %%
class Company:
    Cname='Apple'
    headquarter='California'
    products='iPhone,Apple TV,macOS..'
class Iphone(Company):
    def iphone15(self):
        print('iphone15')
        print('iphone15 plus 128gb')
        print('iphone15 plus 256gb')
        print('iphone15 plus 512gb')
    def iphone14(self):
        print('iphone14')
        print('iphone14 5g 128gb')
        print('iphone14 5g plus 256gb')
        print('iphone14 5g plus 512gb')
class Macbook(Company):
    def macbook_Air(self):
        print('Apple 2022 Macbook Air M1')
        print('Apple 2022 Macbook Air M2')
        print('Apple 2023 Macbook Air Pro M2')
    def macbook_Pro(self):
        print('Apple Macbook Pro M2')
        print('Apple Macbook Pro M2 Max')
        print('Apple Macbook Pro M1 Max')
class User(Iphone,Macbook):
    def __init__(self,n,m):
        self.name=n
        self.mobile=m
    def purchase(self):
        print(Company.Cname)
        print('User name:',self.name)
        print('Mobile :',self.mobile)
obj=User('Akash',7440901753)
obj.purchase()
obj.macbook_Air()
# Out:
# Apple
# User name: Akash
# Mobile : 7440901753
# Apple 2022 Macbook Air M1
# Apple 2022 Macbook Air M2
# Apple 2023 Macbook Air Pro M2

# %% [markdown]
# # Multilevel inheritance

# %%
class RBI:
    bank_roi=6
    def rbi_guideline(self):
        print("Statutory Restrictions")
        print("Advance against bank's own shares")
        print("Restrictions on holding shares in Companies")
        print('Regulatory Restrictions')

class Bank(RBI):
    bank_name='sbi'
    bank_branch='sbi101'
    bank_ifsc=7890
    
    def __init__(self,n,ac,b):
        self.name=n
        self.account=ac
        self.balance=b
    @staticmethod
    def get_data(s):
        data=int(input(f'Enter data for {s}'))
        return data
    @classmethod
    def display_bank(cls):
        print(cls.bank_name)
        print(cls.bank_ifsc)
        print(cls.bank_branch)
        print(cls.bank_roi)

    def display_obj(self):
        print(Bank.bank_name)
        print(Bank.bank_ifsc)
        print(Bank.bank_branch)
        print(Bank.bank_roi)
        print(self.name)
        print(self.account)
        print(self.balance)
    @classmethod
    def modify_roi(cls):
        newroi=cls.get_data('newroi')
        cls.bank_roi=newroi
        print('Modification Successful for roi')
    def withdraw(self):
        amount=self.get_data('withdraw amount')
        if self.balance>=amount and self.balance>0:
            self.balance-=amount
            print('withdraw successful')
        else:
            print('Low balance')
class Bank_v2(Bank):
    def deposit(self):
        data=self.get_data()
        self.balance+=data
        print('Deposited amount:',data)
        print('Total Balance:',self.balance)
obj1=Bank('Akash',556723,1000000)
obj2=Bank('Akku',4981235,10000000)
obj1.modify_roi()
obj1.withdraw()
obj1.display_obj()
# Out:
# Modification Successful for roi
# withdraw successful
# sbi
# 7890
# sbi101
# 5
# Akash
# 556723
# 998000

# %% [markdown]
# # Hierarchical Inheritance

# %%
class Jsp:               #Parent
    Name='Jspider'
    Add='Marathahalli'
    def __init__(self,n,a,m,y):
        self.name=n
        self.age=a
        self.mobile=m
        self.yop=y
    @classmethod
    def Std_details(cls):
        print('Name:',cls.Name)
        print("Address:",cls.Add)

class Pythonfull_d(Jsp):           # First Child
    mentor='Harshad Sir'
    fee=35000
    def __init__(self,n,a,m,y,s):
        super().__init__(n,a,m,y)
        self.stream=s
    def course_details(self):
        print('Python:-')
        print('# Database')
        print('# Web Tech')
        print('# Python')
        print('# Django and Flask')
    @classmethod
    def Std_details(cls):
        super().Std_details()
        print(cls)

class Javafull_d(Jsp):             # Second Child
    mentor="Raveesh Sir"
    fee=36000
    def __init__(self,n,a,m,y,s):
        super().__init__(n,a,m,y)
        self.stream=s
    def course_details(self):
        print('JAVA:-')
        print('# Database')
        print('# Core Java')
        print('# J2EE')
        print('# Frameworks')
        print('# Web Tech')
        print('# Web services')

p=Pythonfull_d('akash',23,7440901753,2022,'automobile')
p.course_details()
j=Javafull_d('akash',23,7440901753,2022,'automobile')
j.course_details()
# Out:
# Python:-
# # Database
# # Web Tech
# # Python
# # Django and Flask
# JAVA:-
# # Database
# # Core Java
# # J2EE
# # Frameworks
# # Web Tech
# # Web services

# %% [markdown]
# # MULTIPLE Inheritance

# %%
class Men:     #First Parent 
    
    def Mdress(self):
        print('Mens Cloths')
        print("Shirts")
        print("Jeans")
        print("Kurta")
        print("T-shirt")
        print('Party wear')
        print('Footwear')
    
    
class Women:    #Second Parent
    
    def Wdress(self):
        print('womens Cloths')
        print("Sarees")
        print("Jeans")
        print("Kurti")
        print("Tops")
        print('Party wear')
        print('Footwear')
          
class Seller(Men,Women):   # Child
    def __init__(self,n,m,a):
        self.name=n
        self.mobile=m
        self.age=a
    
obj=Seller('akash',8081773606,22)
obj.Mdress()
obj.Wdress()
# Out:
# Mens Cloths
# Shirts
# Jeans
# Kurta
# T-shirt
# Party wear
# Footwear
# womens Cloths
# Sarees
# Jeans
# Kurti
# Tops
# Party wear
# Footwear
