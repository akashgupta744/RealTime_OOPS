# %%
class Address:
    def __init__(self,c,s,co):
        self.city=c
        self.state=s
        self.country=co
    
    def display_address(self):
        print('name of city is',self.city)
        print('name of state is',self.state)
        print('name of country is',self.country)
    
bangloreObject=Address('Banglore','karnataka','Bharat')
GwaliorObject=Address('Gwalior','MadhyaPradesh','Bharat')

class Student:
    def __init__(self,n,a,cn,id,no,ado):
        self.sname=n
        self.sage=a
        self.clgname=cn
        self.sid=id
        self.pno=no
        self.saddress=ado
    
    def student_info(self):
        print('name of student is',self.sname)
        print('age of student is',self.sage)
        print('college name of student',self.clgname)
        print('id of student is',self.sid)
        print('number of the student',self.pno)
        print('Address the student is')
        self.saddress.display_address()



class Teacher:
    def __init__(self,n,a,id,no,ado):
        self.Tname=n
        self.Tage=a
        self.Texperince=id
        self.pno=no
        self.saddress=ado
    
    def Teacher_info(self):
        print('name of Teacher is',self.Tname)
        print('age of Teacher is',self.Tage)
        print('Experince of Teacher is',self.Texperince)
        print('number of the Teacher',self.pno)
        print('Address the Teacher is')
        self.saddress.display_address()

class Doctor:
    def __init__(self,n,a,id,no,ado):
        self.Dname=n
        self.Dage=a
        self.Dexperince=id
        self.pno=no
        self.saddress=ado
    
    def Doctor_info(self):
        print('name of Doctor is',self.Dname)
        print('age of Doctor is',self.Dage)
        print('Experince of Doctor is',self.Dexperince)
        print('number of Doctor',self.pno)
        print('Address the Doctor is')
        self.saddress.display_address()

Akash=Student('Akash Gupta',23,'RJIT',181005,7440901753,bangloreObject)
Akash.student_info()

print()

Harshad=Teacher('Shaik Harshad Vali',28,'3.8 yrs',8985338755,bangloreObject)
Harshad.Teacher_info()

print()


harry=Doctor('Dr.Harry',31,'4.6 yrs',9895467723,bangloreObject)
harry.Doctor_info()
# Out:
# name of student is Akash Gupta
# age of student is 23
# college name of student RJIT
# id of student is 181005
# number of the student 7440901753
# Address the student is
# name of city is Banglore
# name of state is karnataka
# name of country is Bharat
#
# name of Teacher is Shaik Harshad Vali
# age of Teacher is 28
# Experince of Teacher is 3.8 yrs
# number of the Teacher 8985338755
# Address the Teacher is
# name of city is Banglore
# name of state is karnataka
# name of country is Bharat
#
# name of Doctor is Dr.Harry
# age of Doctor is 31
# Experince of Doctor is 4.6 yrs
# number of Doctor 9895467723
# Address the Doctor is
# name of city is Banglore
# name of state is karnataka
# name of country is Bharat

# %%
# creating object of adress class inside the constructor of trainer class
class Address:
    def __init__(self,c,s,co):
        self.city=c
        self.state=s
        self.country=co
    
    def display_address(self):
        print('name of city is',self.city)
        print('name of state is',self.state)
        print('name of country is',self.country)
    
class Trainer:
    def __init__(self,n,sub,e):
        self.Tname=n
        self.Tsub=sub
        self.Texperince=e
        c=input('enter city')
        s=input('enter state')
        co=input('enter country')
        ACO=Address(c,s,co)
        self.Taddress=ACO
        
    def trainer_info(self):
        print('name of Teacher is',self.Tname)
        print('subject of Teacher is',self.Tsub)
        print('Experince of Teacher is',self.Texperince)
        print('Address of Teacher is')
        self.Taddress.display_address()
Akash=Trainer('Akash Gupta','Python',1)
Akash.trainer_info()
# Out:
# name of Teacher is Akash Gupta
# subject of Teacher is Python
# Experince of Teacher is 1
# Address of Teacher is
# name of city is banglore
# name of state is karnataka
# name of country is bharat

# %%
# creating object of adress class inside the constructor of trainer class
class Car:
    def __init__(self,cn,cc,cm):
        self.Cname=cn
        self.Ccolour=cc
        self.Cmodel=cm
    
    def car_started(self):
        print(self.Cname,'is started')
    def car_accelerated(self):
        print(self.Cname,'is accelerated')
    def car_stop(self):
        print(self.Cname,'is stop')


    
class Driver:
    def __init__(self,n,ag,e):
        self.Dname=n
        self.Dage=ag
        self.Dexperince=e
        N=input('enter Car Name')
        C=input('enter Car colour')
        M=input('enter Car Model')
        ACO=Car(N,C,M)
        self.Dcar=ACO

    def car_driving(self):
        print(self.Dname,'has started the car')
        self.Dcar.car_started()
        self.Dcar.car_accelerated()
        self.Dcar.car_stop()
        print(self.Dname,'has started the car')

Akash=Driver('Akash Gupta',23,'2yr')
Akash.car_driving()
# Out:
# Akash Gupta has started the car
# Audi is started
# Audi is accelerated
# Audi is stop
# Akash Gupta has started the car

# %%
class Player:
    def __init__(self,n,co,a,nom,nor,now):
        self.pname=n
        self.pcountry=co
        self.page=a
        self.pmatches=nom
        self.pruns=nor
        self.pwickets=now

class Team:
    def __init__(self,n):
        self.nop=n
        self.player_list=[]
        for i in range(1,self.nop+1):
            pn=input(f'{i} player name') #Virat
            pc=input(f'{i} player country') #india
            pa=input(f'{i} player age') #34
            pnm=int(input(f'{i} player no. of matches'))
            pnr=int(input(f'{i} player no. of Runs'))
            pnw=int(input(f'{i} player no. of Wickets'))
            pao=Player(pn,pc,pa,pnm,pnr,pnw)
            self.player_list.append(pao)

    
    def total_score(self):
        total_run=0
        for i in self.player_list:
            total_run+=i.pruns
        print('Total score =',total_run)

    def max_run(self):
        max=0
        obj=''
        for i in self.player_list:
            if i.pruns>max:
                max=i.pruns
                obj=i
        print(f'max runs of {obj.pname} = {max}')

    def max_wickets(self):
        max=0
        obj=''
        for i in self.player_list:
            if i.pwickets>max:
                max=i.pwickets
                obj=i
        print(f'max wickets of {obj.pname} = {max}')
    
    def max_matches(self):
        max=0
        obj=''
        for i in self.player_list:
            if i.pmatches>max:
                max=i.pmatches
                obj=i
        print(f'max matches played by {obj.pname} = {max}')


        
india=Team(int(input('no_players')))       
india.total_score() 
india.max_run()
india.max_wickets()
india.max_matches()
# Out:
# Total score = 219
# max runs of virat = 100
# max wickets of bumrah = 9
# max matches played by rahul = 150
